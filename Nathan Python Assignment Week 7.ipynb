# %%
from bs4 import BeautifulSoup
import requests

url = raw_input("Enter a website to extract URLs ")
r= requests.get("http://" + url)
data = r.text
bs = BeautifulSoup(data)
for link in bs.find_all('a'):
    print(link.get('href'))
# Out:
# Enter a website to extract URLs from en.wikipedia.org/wiki/Tim_Howard
# None
# #mw-navigation
# #p-search
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Tim_Howard_(attorney)
# /wiki/Tim_Howard_(sheriff)
# /wiki/File:Tim_Howard_2011_(cropped).jpg
# /wiki/United_States_men%27s_national_soccer_team
# #cite_note-Hugman2010-11_203-1
# #cite_note-Hugman2010-11_203-1
# /wiki/North_Brunswick,_New_Jersey
# #cite_note-Hugman2010-11_203-1
# /wiki/Goalkeeper_(association_football)
# /wiki/Everton_F.C.
# /wiki/North_Jersey_Imperials
# /wiki/New_York_Red_Bulls
# /wiki/MLS_Pro-40
# /wiki/Manchester_United_F.C.
# /wiki/Everton_F.C.
# /wiki/Everton_F.C.
# /wiki/United_States_men%27s_national_soccer_team
# /wiki/Association_football
# /wiki/Goalkeeper_(association_football)
# /wiki/Everton_F.C.
# /wiki/United_States_men%27s_national_soccer_team
# /wiki/North_Jersey_Imperials
# /wiki/New_York_Red_Bulls
# /wiki/Manchester_United_F.C.
# /wiki/2003_FA_Community_Shield
# /wiki/2003%E2%80%9304_FA_Cup
# ...

# %%
http://en.wikipedia.org/wiki/Tim_Howard
# Out:
#   File "<ipython-input-3-96d1aa6c76fa>", line 1
#     http://en.wikipedia.org/wiki/Tim_Howard
#         ^
# SyntaxError: invalid syntax
